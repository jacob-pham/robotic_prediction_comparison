# %%
#train on eth
# %run tcn_train.py --scene eth

#test and evaluate on eth
# %run tcn_test.py --scene eth

#display the image
from PIL import Image
from pathlib import Path

img_path = Path.cwd() / "predictions_eth.png"
if img_path.exists():
    display(Image.open(img_path))
# Out:
# Using device: cpu
# Training on scene: ETH
# Train trajectories: 30307  |  Val trajectories: 5422
# Epochs:   2%|▏         | 1/50 [00:23<18:53, 23.13s/it]
#   Epoch   1/50  |  train loss: 1.059279  |  val loss: 0.872741
#   New best val loss 0.872741 — checkpoint saved.
# Epochs:   4%|▍         | 2/50 [00:44<17:33, 21.95s/it]
#   Epoch   2/50  |  train loss: 0.822387  |  val loss: 0.814413
#   New best val loss 0.814413 — checkpoint saved.
# Epochs:   6%|▌         | 3/50 [01:08<17:50, 22.77s/it]
#   Epoch   3/50  |  train loss: 0.793620  |  val loss: 0.795670
#   New best val loss 0.795670 — checkpoint saved.
# Epochs:   8%|▊         | 4/50 [01:30<17:29, 22.81s/it]
#   Epoch   4/50  |  train loss: 0.777257  |  val loss: 0.775279
#   New best val loss 0.775279 — checkpoint saved.
# Epochs:  10%|█         | 5/50 [01:55<17:28, 23.31s/it]
#   Epoch   5/50  |  train loss: 0.768907  |  val loss: 0.776556
# Epochs:  12%|█▏        | 6/50 [02:22<18:14, 24.88s/it]
# ...

# %%
#train on hotel
# %run tcn_train.py --scene hotel

#test and evaluate hotel
# %run tcn_test.py --scene hotel

#display the image
from PIL import Image
from pathlib import Path

img_path = Path.cwd() / "predictions_hotel.png"
if img_path.exists():
    display(Image.open(img_path))
# Out:
# Using device: cpu
# Training on scene: HOTEL
# Train trajectories: 29676  |  Val trajectories: 5203
# Epochs:   2%|▏         | 1/50 [00:19<15:40, 19.19s/it]
#   Epoch   1/50  |  train loss: 1.060694  |  val loss: 0.917713
#   New best val loss 0.917713 — checkpoint saved.
# Epochs:   4%|▍         | 2/50 [00:37<14:59, 18.73s/it]
#   Epoch   2/50  |  train loss: 0.826149  |  val loss: 0.862290
#   New best val loss 0.862290 — checkpoint saved.
# Epochs:   6%|▌         | 3/50 [00:57<15:11, 19.39s/it]
#   Epoch   3/50  |  train loss: 0.798298  |  val loss: 0.849007
#   New best val loss 0.849007 — checkpoint saved.
# Epochs:   8%|▊         | 4/50 [01:19<15:34, 20.31s/it]
#   Epoch   4/50  |  train loss: 0.786793  |  val loss: 0.857745
# Epochs:  10%|█         | 5/50 [01:42<15:55, 21.23s/it]
#   Epoch   5/50  |  train loss: 0.775164  |  val loss: 0.827404
#   New best val loss 0.827404 — checkpoint saved.
# Epochs:  12%|█▏        | 6/50 [02:05<15:58, 21.78s/it]
# ...

# %%
#train on univ
# %run tcn_train.py --scene univ

#test and evaluate univ
# %run tcn_test.py --scene univ

#display the image
from PIL import Image
from pathlib import Path

img_path = Path.cwd() / "predictions_univ.png"
if img_path.exists():
    display(Image.open(img_path))
# Out:
# Using device: cpu
# Training on scene: UNIV
# Train trajectories: 9874  |  Val trajectories: 2800
# Epochs:   2%|▏         | 1/50 [00:05<04:51,  5.95s/it]
#   Epoch   1/50  |  train loss: 1.857530  |  val loss: 1.151796
#   New best val loss 1.151796 — checkpoint saved.
# Epochs:   4%|▍         | 2/50 [00:11<04:42,  5.88s/it]
#   Epoch   2/50  |  train loss: 1.193693  |  val loss: 1.065539
#   New best val loss 1.065539 — checkpoint saved.
# Epochs:   6%|▌         | 3/50 [00:18<04:44,  6.05s/it]
#   Epoch   3/50  |  train loss: 1.103827  |  val loss: 0.979131
#   New best val loss 0.979131 — checkpoint saved.
# Epochs:   8%|▊         | 4/50 [00:24<04:44,  6.19s/it]
#   Epoch   4/50  |  train loss: 1.076970  |  val loss: 0.979428
# Epochs:  10%|█         | 5/50 [00:30<04:42,  6.28s/it]
#   Epoch   5/50  |  train loss: 1.055954  |  val loss: 0.952650
#   New best val loss 0.952650 — checkpoint saved.
# Epochs:  12%|█▏        | 6/50 [00:40<05:21,  7.31s/it]
# ...

# %%
#train on zara1
# %run tcn_train.py --scene zara1

#test and evaluate zara1
# %run tcn_test.py --scene zara1

#display the image
from PIL import Image
from pathlib import Path

img_path = Path.cwd() / "predictions_zara1.png"
if img_path.exists():
    display(Image.open(img_path))
# Out:
# Using device: cpu
# Training on scene: ZARA1
# Train trajectories: 28577  |  Val trajectories: 5184
# Epochs:   2%|▏         | 1/50 [00:18<15:08, 18.54s/it]
#   Epoch   1/50  |  train loss: 1.023667  |  val loss: 0.879925
#   New best val loss 0.879925 — checkpoint saved.
# Epochs:   4%|▍         | 2/50 [00:37<14:59, 18.74s/it]
#   Epoch   2/50  |  train loss: 0.799446  |  val loss: 0.830366
#   New best val loss 0.830366 — checkpoint saved.
# Epochs:   6%|▌         | 3/50 [00:59<15:46, 20.15s/it]
#   Epoch   3/50  |  train loss: 0.773432  |  val loss: 0.832357
# Epochs:   8%|▊         | 4/50 [01:20<15:50, 20.67s/it]
#   Epoch   4/50  |  train loss: 0.756337  |  val loss: 0.796945
#   New best val loss 0.796945 — checkpoint saved.
# Epochs:  10%|█         | 5/50 [01:41<15:32, 20.71s/it]
#   Epoch   5/50  |  train loss: 0.746159  |  val loss: 0.806422
# Epochs:  12%|█▏        | 6/50 [02:00<14:38, 19.98s/it]
#   Epoch   6/50  |  train loss: 0.736980  |  val loss: 0.790594
# ...

# %%
#train on zara2
# %run tcn_train.py --scene zara2

#test and evaluate zara2
# %run tcn_test.py --scene zara2

#display the image
from PIL import Image
from pathlib import Path

img_path = Path.cwd() / "predictions_zara2.png"
if img_path.exists():
    display(Image.open(img_path))
# Out:
# Using device: cpu
# Training on scene: ZARA2
# Train trajectories: 26076  |  Val trajectories: 4262
# Epochs:   2%|▏         | 1/50 [00:16<13:44, 16.83s/it]
#   Epoch   1/50  |  train loss: 1.092426  |  val loss: 0.962055
#   New best val loss 0.962055 — checkpoint saved.
# Epochs:   4%|▍         | 2/50 [00:31<12:37, 15.78s/it]
#   Epoch   2/50  |  train loss: 0.828227  |  val loss: 0.923721
#   New best val loss 0.923721 — checkpoint saved.
# Epochs:   6%|▌         | 3/50 [00:47<12:24, 15.84s/it]
#   Epoch   3/50  |  train loss: 0.799951  |  val loss: 0.918654
#   New best val loss 0.918654 — checkpoint saved.
# Epochs:   8%|▊         | 4/50 [01:03<12:11, 15.91s/it]
#   Epoch   4/50  |  train loss: 0.783104  |  val loss: 0.870780
#   New best val loss 0.870780 — checkpoint saved.
# Epochs:  10%|█         | 5/50 [01:19<11:47, 15.71s/it]
#   Epoch   5/50  |  train loss: 0.773510  |  val loss: 0.861556
#   New best val loss 0.861556 — checkpoint saved.
# ...
